# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Define the train directory path
train_dir = '/content/drive/MyDrive/FruitinAmazon/train'

# Get the list of class directories
class_dirs = [d for d in os.listdir(train_dir) if os.path.isdir(os.path.join(train_dir, d))]
class_dirs.sort()  # Sort for consistent order
print(f"Found {len(class_dirs)} classes: {class_dirs}")

# Select one random image from each class
images = []
class_names = []
for class_dir in class_dirs:
    class_path = os.path.join(train_dir, class_dir)
    image_files = [f for f in os.listdir(class_path) if f.endswith(('.jpg', '.jpeg', '.png'))]
    if image_files:  # Ensure there’s at least one image
        random_image = random.choice(image_files)
        image_path = os.path.join(class_path, random_image)
        images.append(image_path)
        class_names.append(class_dir)

# Check if we have images to display
if not images:
    raise ValueError("No images found in the dataset!")

# Display images in a 2-row grid
rows = 2
cols = (len(images) + 1) // 2  # Ceiling division to fit all classes
fig, axes = plt.subplots(rows, cols, figsize=(15, 10))  # Adjust figure size as needed
fig.suptitle("Random Images from Each Class", fontsize=16)

# Flatten axes array for easier indexing
axes = axes.flatten()

# Plot each image
for i, (image_path, class_name) in enumerate(zip(images, class_names)):
    img = mpimg.imread(image_path)
    axes[i].imshow(img)
    axes[i].set_title(class_name)
    axes[i].axis('off')  # Hide axes

# Hide any unused subplots (if odd number of classes)
for j in range(i + 1, len(axes)):
    axes[j].axis('off')

plt.tight_layout()
plt.show()
# Out:
# Found 6 classes: ['acai', 'cupuacu', 'graviola', 'guarana', 'pupunha', 'tucuma']

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import numpy as np

# Define dataset paths
train_dir = '/content/drive/MyDrive/FruitinAmazon/train'
test_dir = '/content/drive/MyDrive/FruitinAmazon/test'

# Load datasets
train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=(128, 128),
    batch_size=16,
    label_mode='categorical',
    shuffle=True
)

test_dataset = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=(128, 128),
    batch_size=16,
    label_mode='categorical',
    shuffle=False
)

# Store the number of classes before mapping
num_classes = len(train_dataset.class_names)

# Normalize images
def normalize_img(image, label):
    return tf.cast(image, tf.float32) / 255.0, label

train_dataset = train_dataset.map(normalize_img)
test_dataset = test_dataset.map(normalize_img)

# Define CNN model
model = keras.Sequential([
    keras.Input(shape=(128, 128, 3)),
    layers.Conv2D(32, (3, 3), padding='same', strides=1, activation="relu"),  # Conv1
    layers.MaxPooling2D((2, 2), strides=2),                            # Pool1
    layers.Conv2D(32, (3, 3), padding='same', strides=1, activation="relu"),  # Conv2
    layers.MaxPooling2D((2, 2), strides=2),                            # Pool2
    layers.Flatten(),                                                  # Flatten
    layers.Dense(64, activation="relu"),                               # Hidden 1
    layers.Dense(128, activation="relu"),                              # Hidden 2
    layers.Dense(num_classes, activation="softmax")                    # Output (6)
])

model.summary()

# Compile model
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

checkpoint = ModelCheckpoint(
    'best_model.keras',  # Save best model
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=20,  # Stop after 20 epochs with no improvement
    mode='max',
    verbose=1
)

# Train model
histroy = model.fit(
    train_dataset,
    epochs=250,
    validation_data=test_dataset,
    callbacks=[checkpoint, early_stopping]
)

# Evaluate model
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.4f}")

# Make predictions on one batch
for images, labels in test_dataset.take(1):
    predictions = model.predict(images)
    predicted_labels = np.argmax(predictions, axis=1)
    actual_labels = np.argmax(labels, axis=1)
    print("Predicted labels:", predicted_labels[:5])
    print("Actual labels: ", actual_labels[:5])
    break
# Out:
# Found 90 files belonging to 6 classes.
# Found 30 files belonging to 6 classes.
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_22 (Conv2D)                   │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_22 (MaxPooling2D)      │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_23 (Conv2D)                   │ (None, 64, 64, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_23 (MaxPooling2D)      │ (None, 32, 32, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_11 (Flatten)                 │ (None, 32768)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_26 (Dense)                     │ (None, 64)                  │       2,097,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_27 (Dense)                     │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_28 (Dense)                     │ (None, 6)                   │             774 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,116,454 (8.07 MB)
#  Trainable params: 2,116,454 (8.07 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.1360 - loss: 2.0072
# Epoch 1: val_accuracy improved from -inf to 0.26667, saving model to best_model.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 385ms/step - accuracy: 0.1388 - loss: 2.0011 - val_accuracy: 0.2667 - val_loss: 1.7514
# Epoch 2/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.2899 - loss: 1.7167
# Epoch 2: val_accuracy did not improve from 0.26667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 326ms/step - accuracy: 0.2866 - loss: 1.7145 - val_accuracy: 0.2333 - val_loss: 1.6319
# Epoch 3/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.3729 - loss: 1.5405
# Epoch 3: val_accuracy improved from 0.26667 to 0.40000, saving model to best_model.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 354ms/step - accuracy: 0.3736 - loss: 1.5441 - val_accuracy: 0.4000 - val_loss: 1.4434
# Epoch 4/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.5273 - loss: 1.3686
# Epoch 4: val_accuracy improved from 0.40000 to 0.46667, saving model to best_model.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 537ms/step - accuracy: 0.5361 - loss: 1.3544 - val_accuracy: 0.4667 - val_loss: 1.3415
# Epoch 5/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.6494 - loss: 1.0377
# Epoch 5: val_accuracy did not improve from 0.46667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 407ms/step - accuracy: 0.6598 - loss: 1.0250 - val_accuracy: 0.4667 - val_loss: 1.3145
# Epoch 6/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.7512 - loss: 0.7558
# Epoch 6: val_accuracy improved from 0.46667 to 0.66667, saving model to best_model.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 343ms/step - accuracy: 0.7502 - loss: 0.7496 - val_accuracy: 0.6667 - val_loss: 1.0167
# Epoch 7/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.8061 - loss: 0.4904
# Epoch 7: val_accuracy did not improve from 0.66667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 321ms/step - accuracy: 0.8037 - loss: 0.4941 - val_accuracy: 0.6000 - val_loss: 1.0307
# Epoch 8/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.9053 - loss: 0.3616
# Epoch 8: val_accuracy did not improve from 0.66667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 320ms/step - accuracy: 0.9014 - loss: 0.3609 - val_accuracy: 0.6333 - val_loss: 0.9253
# Epoch 9/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.9490 - loss: 0.2237
# Epoch 9: val_accuracy did not improve from 0.66667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 508ms/step - accuracy: 0.9404 - loss: 0.2368 - val_accuracy: 0.6333 - val_loss: 1.1617
# Epoch 10/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.9884 - loss: 0.1599
# Epoch 10: val_accuracy did not improve from 0.66667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 326ms/step - accuracy: 0.9837 - loss: 0.1652 - val_accuracy: 0.5000 - val_loss: 0.9866
# Epoch 11/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9696 - loss: 0.1604
# Epoch 11: val_accuracy did not improve from 0.66667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 323ms/step - accuracy: 0.9707 - loss: 0.1562 - val_accuracy: 0.6000 - val_loss: 1.0744
# Epoch 12/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9808 - loss: 0.0942
# Epoch 12: val_accuracy did not improve from 0.66667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 326ms/step - accuracy: 0.9804 - loss: 0.0946 - val_accuracy: 0.5667 - val_loss: 1.1534
# Epoch 13/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 1.0000 - loss: 0.0214
# Epoch 13: val_accuracy did not improve from 0.66667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 325ms/step - accuracy: 1.0000 - loss: 0.0216 - val_accuracy: 0.6667 - val_loss: 0.7945
# Epoch 14/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 1.0000 - loss: 0.0208
# Epoch 14: val_accuracy did not improve from 0.66667
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 561ms/step - accuracy: 1.0000 - loss: 0.0204 - val_accuracy: 0.6667 - val_loss: 0.8001
# Epoch 15/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 0.0067
# Epoch 15: val_accuracy improved from 0.66667 to 0.73333, saving model to best_model.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 347ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.7333 - val_loss: 0.8161
# Epoch 16/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 16: val_accuracy did not improve from 0.73333
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 318ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.7333 - val_loss: 0.8769
# Epoch 17/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 17: val_accuracy improved from 0.73333 to 0.80000, saving model to best_model.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 354ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.8000 - val_loss: 0.8974
# Epoch 18/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 18: val_accuracy did not improve from 0.80000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 321ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.7667 - val_loss: 0.9043
# Epoch 19/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 19: val_accuracy did not improve from 0.80000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 599ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.7000 - val_loss: 0.8726
# Epoch 20/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 1.0000 - loss: 9.2399e-04
# Epoch 20: val_accuracy did not improve from 0.80000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 317ms/step - accuracy: 1.0000 - loss: 9.1773e-04 - val_accuracy: 0.7333 - val_loss: 0.8329
# Epoch 21/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 1.0000 - loss: 7.9153e-04
# Epoch 21: val_accuracy did not improve from 0.80000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 319ms/step - accuracy: 1.0000 - loss: 7.8336e-04 - val_accuracy: 0.7333 - val_loss: 0.8171
# Epoch 22/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 1.0000 - loss: 6.0099e-04
# Epoch 22: val_accuracy did not improve from 0.80000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 314ms/step - accuracy: 1.0000 - loss: 6.0632e-04 - val_accuracy: 0.7333 - val_loss: 0.8121
# Epoch 23/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 1.0000 - loss: 5.1052e-04
# Epoch 23: val_accuracy did not improve from 0.80000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 372ms/step - accuracy: 1.0000 - loss: 5.2042e-04 - val_accuracy: 0.7667 - val_loss: 0.8175
# Epoch 24/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 1.0000 - loss: 5.8702e-04
# Epoch 24: val_accuracy did not improve from 0.80000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 504ms/step - accuracy: 1.0000 - loss: 5.8061e-04 - val_accuracy: 0.7667 - val_loss: 0.8273
# Epoch 25/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 1.0000 - loss: 5.3622e-04
# Epoch 25: val_accuracy did not improve from 0.80000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 336ms/step - accuracy: 1.0000 - loss: 5.3218e-04 - val_accuracy: 0.7667 - val_loss: 0.8385
# Epoch 26/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 1.0000 - loss: 4.6774e-04
# Epoch 26: val_accuracy did not improve from 0.80000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 323ms/step - accuracy: 1.0000 - loss: 4.6847e-04 - val_accuracy: 0.7667 - val_loss: 0.8427
# Epoch 27/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 1.0000 - loss: 4.3321e-04
# Epoch 27: val_accuracy did not improve from 0.80000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 324ms/step - accuracy: 1.0000 - loss: 4.3485e-04 - val_accuracy: 0.7667 - val_loss: 0.8491
# Epoch 28/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 1.0000 - loss: 3.9211e-04
# Epoch 28: val_accuracy did not improve from 0.80000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 534ms/step - accuracy: 1.0000 - loss: 3.9608e-04 - val_accuracy: 0.7667 - val_loss: 0.8495
# Epoch 29/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 1.0000 - loss: 4.5312e-04
# Epoch 29: val_accuracy did not improve from 0.80000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 317ms/step - accuracy: 1.0000 - loss: 4.4500e-04 - val_accuracy: 0.7667 - val_loss: 0.8492
# Epoch 30/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 1.0000 - loss: 3.8654e-04
# Epoch 30: val_accuracy did not improve from 0.80000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 326ms/step - accuracy: 1.0000 - loss: 3.8507e-04 - val_accuracy: 0.7667 - val_loss: 0.8473
# Epoch 31/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 1.0000 - loss: 2.7950e-04
# Epoch 31: val_accuracy did not improve from 0.80000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 322ms/step - accuracy: 1.0000 - loss: 2.9018e-04 - val_accuracy: 0.7667 - val_loss: 0.8541
# Epoch 32/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 1.0000 - loss: 3.2283e-04
# Epoch 32: val_accuracy did not improve from 0.80000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 318ms/step - accuracy: 1.0000 - loss: 3.2489e-04 - val_accuracy: 0.7667 - val_loss: 0.8606
# Epoch 33/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 1.0000 - loss: 2.7611e-04
# Epoch 33: val_accuracy did not improve from 0.80000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 556ms/step - accuracy: 1.0000 - loss: 2.8237e-04 - val_accuracy: 0.7667 - val_loss: 0.8659
# Epoch 34/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 1.0000 - loss: 3.2838e-04
# Epoch 34: val_accuracy did not improve from 0.80000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 339ms/step - accuracy: 1.0000 - loss: 3.2519e-04 - val_accuracy: 0.7667 - val_loss: 0.8692
# Epoch 35/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 1.0000 - loss: 2.7035e-04
# Epoch 35: val_accuracy did not improve from 0.80000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 334ms/step - accuracy: 1.0000 - loss: 2.7322e-04 - val_accuracy: 0.7667 - val_loss: 0.8775
# Epoch 36/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 1.0000 - loss: 2.9330e-04
# Epoch 36: val_accuracy did not improve from 0.80000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 332ms/step - accuracy: 1.0000 - loss: 2.9114e-04 - val_accuracy: 0.7667 - val_loss: 0.8845
# Epoch 37/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 1.0000 - loss: 2.6131e-04
# Epoch 37: val_accuracy did not improve from 0.80000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 325ms/step - accuracy: 1.0000 - loss: 2.6175e-04 - val_accuracy: 0.7667 - val_loss: 0.8899
# Epoch 37: early stopping
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8236 - loss: 0.6645
# Test accuracy: 0.7667
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7c77ef967920> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# Predicted labels: [0 0 0 0 0]
# Actual labels:  [0 0 0 0 0]

# %%
history_dict = histroy.history
epochs = range(1, len(history_dict['loss']) + 1)
train_loss = history_dict['loss']
val_loss = history_dict['val_loss']
train_acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

# Create subplots: 1 row, 2 columns
plt.figure(figsize=(12, 5))

# Plot 1: Loss
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'b-', label='Training Loss')
plt.plot(epochs, val_loss, 'r-', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Plot 2: Accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, train_acc, 'b-', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r-', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Adjust layout and display
plt.tight_layout()
plt.show()

# %%
model.save('fruitdetection.h5')
loaded_model = keras.models.load_model('fruitdetection.h5')

print('model saved to fruitdetection.h5')
print('model loaded from fruitdetection.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved to fruitdetection.h5
# model loaded from fruitdetection.h5

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
from sklearn.metrics import classification_report
loaded_model = keras.models.load_model('fruitdetection.h5')
print("Model loaded for predictions")

# Collect all test images and labels
all_images = []
all_labels = []
for images, labels in test_dataset:
    all_images.append(images.numpy())
    all_labels.append(labels.numpy())

# Concatenate batches into single arrays
test_images = np.concatenate(all_images, axis=0)  # Shape: (30, 128, 128, 3)
test_labels_onehot = np.concatenate(all_labels, axis=0)  # Shape: (30, 6)

# Make predictions
predictions = loaded_model.predict(test_images)
predicted_labels = np.argmax(predictions, axis=1)  # Convert probabilities to class indices
true_labels = np.argmax(test_labels_onehot, axis=1)  # Convert one-hot to class indices

# Get class names from the dataset
class_names = test_data.class_names
print(f"Class names: {class_names}")

# Generate classification report
report = classification_report(true_labels, predicted_labels, target_names=class_names)
print("Classification Report:\n", report)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded for predictions
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# Class names: ['acai', 'cupuacu', 'graviola', 'guarana', 'pupunha', 'tucuma']
# Classification Report:
#                precision    recall  f1-score   support
#
#         acai       0.83      1.00      0.91         5
#      cupuacu       0.57      0.80      0.67         5
#     graviola       0.83      1.00      0.91         5
#      guarana       0.80      0.80      0.80         5
#      pupunha       0.75      0.60      0.67         5
#       tucuma       1.00      0.40      0.57         5
#
#     accuracy                           0.77        30
#    macro avg       0.80      0.77      0.75        30
# weighted avg       0.80      0.77      0.75        30
